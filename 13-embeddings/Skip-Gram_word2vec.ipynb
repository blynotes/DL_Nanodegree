# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:19, 1.58MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
words.count("of")
# Out:
# 593677

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_cnts = Counter(int_words)
total_cnt = len(int_words)
# Get the frequency of each word
freqs = {word: cnt/total_cnt for word, cnt in word_cnts.items()}
# Get the prob that we drop based on equation above.
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_cnts}

# Drop randomly uniform over entire dataset.
train_words = [w for w in int_words if random.random() < (1 - p_drop[w])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = max(idx - R, 0)
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])    
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)
# Out:
# WARNING:tensorflow:From /home/stephen/python/anaconda3/envs/dlnd/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/stephen/python/anaconda3/envs/dlnd/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/stephen/python/anaconda3/envs/dlnd/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-22-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6682 0.0208 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6180 0.0175 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4928 0.0177 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6294 0.0174 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4834 0.0177 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5307 0.0178 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5386 0.0176 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5569 0.0177 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4771 0.0176 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4169 0.0176 sec/batch
# Nearest to often: kinetics, diaper, suffices, ceased, khadijah, bak, strongholds, mimosa,
# Nearest to two: sibylla, solemnly, severity, indisputably, tough, divination, crooked, provision,
# Nearest to at: bernhardt, corporate, dupont, antidepressant, dispensationalism, rods, subtext, sly,
# Nearest to world: astrometric, kempo, unbroken, cyrillic, mast, reporting, wct, mitrokhin,
# Nearest to th: nail, practitioner, chukchi, unfolded, rommel, shia, modifications, stray,
# Nearest to have: insolvent, subsystems, seamlessly, anthrax, gulf, assassinated, tower, ba,
# Nearest to people: amidst, harming, cassell, leaflet, mercian, tumor, viable, stifled,
# Nearest to however: decayed, aea, streaming, suitcases, micromachining, sindh, siais, rifles,
# Nearest to articles: metre, fealty, ruthless, ramesses, sutton, similars, burkert, forwards,
# Nearest to scale: definitively, governmental, moussa, brochure, prequel, anchor, pln, laine,
# Nearest to rise: rouse, amputation, misapplication, terrence, tem, annuity, anthemius, proponent,
# Nearest to know: apoptosis, pda, cropland, xenophanes, dictatorial, retrofitted, minurso, hieroglyph,
# Nearest to bbc: illustrations, parenting, espy, fluoxetine, ups, lalr, leicestershire, norwalk,
# Nearest to bill: disestablished, communist, dans, blatant, weh, merrick, lazarus, chow,
# Nearest to active: inundation, pineal, higham, freehold, hanafi, atlases, slovakia, golem,
# Nearest to derived: crushed, pressed, criticizing, cip, boycott, centurion, supplanting, resettled,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4743 0.0183 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3818 0.0178 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3136 0.0173 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2356 0.0173 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2137 0.0172 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1577 0.0172 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0895 0.0174 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0727 0.0175 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0032 0.0174 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9839 0.0173 sec/batch
# Nearest to often: kinetics, ceased, mormons, supporting, hunter, suffices, forming, f,
# Nearest to two: sibylla, solemnly, tough, divination, severity, secret, indisputably, database,
# Nearest to at: corporate, nearly, tubes, dupont, bernhardt, subtext, sly, antidepressant,
# Nearest to world: unbroken, astrometric, cyrillic, reporting, explosion, to, mast, kempo,
# Nearest to th: nail, department, york, modifications, selling, notation, attempted, practitioner,
# Nearest to have: insolvent, seamlessly, level, hunter, subsystems, charles, tower, switches,
# Nearest to people: amidst, harming, leaflet, cassell, viable, gradient, tumor, mercian,
# Nearest to however: decayed, framework, city, attribute, establish, infinity, agree, sindh,
# Nearest to articles: metre, great, fealty, ruthless, sutton, forwards, burkert, ramesses,
# Nearest to scale: governmental, definitively, moussa, defeat, anchor, note, prequel, countermeasures,
# Nearest to rise: misapplication, tem, rouse, doctors, amputation, anthemius, century, disengagement,
# Nearest to know: these, retrofitted, pda, dictatorial, cropland, false, anarcho, within,
# Nearest to bbc: illustrations, parenting, espy, ups, railroads, fluoxetine, leicestershire, anymore,
# Nearest to bill: disestablished, communist, publishes, threw, dans, fulani, weh, adjust,
# Nearest to active: freehold, york, slovakia, golem, higham, inundation, hanafi, pineal,
# Nearest to derived: pressed, crushed, future, criticizing, doctrine, raised, subway, landscape,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9438 0.0183 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8915 0.0174 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8971 0.0174 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8461 0.0175 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8195 0.0177 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8151 0.0176 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7973 0.0177 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7892 0.0175 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7722 0.0176 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7585 0.0175 sec/batch
# Nearest to often: kinetics, suffices, mormons, strongholds, wicked, falsely, mimosa, ceased,
# Nearest to two: sibylla, tough, solemnly, divination, seminar, veteran, cooperation, rick,
# Nearest to at: corporate, bernhardt, fellowship, rods, subtext, nearly, dupont, hire,
# Nearest to world: unbroken, astrometric, reporting, explosion, icj, cyrillic, mast, mitrokhin,
# Nearest to th: notation, nail, sizeable, selling, shipments, unfolded, careers, cecil,
# Nearest to have: seamlessly, insolvent, subsystems, exposed, switches, assassinated, anthrax, gulf,
# Nearest to people: amidst, harming, leaflet, cassell, gradient, tumor, stifled, ills,
# Nearest to however: decayed, competent, agree, attribute, streaming, revenge, enmity, establish,
# Nearest to articles: metre, great, fealty, ruthless, sutton, forwards, burkert, historians,
# Nearest to scale: governmental, definitively, moussa, defeat, prequel, countermeasures, anchor, stopwatch,
# Nearest to rise: misapplication, tem, rouse, proponent, terrence, annuity, amputation, doctors,
# Nearest to know: retrofitted, these, pda, dictatorial, cropland, false, existence, anarcho,
# Nearest to bbc: illustrations, ups, espy, parenting, anymore, railroads, prosperity, fluoxetine,
# Nearest to bill: communist, disestablished, publishes, fulani, threw, live, dans, blatant,
# Nearest to active: slovakia, golem, freehold, higham, hanafi, inundation, negated, viral,
# Nearest to derived: pressed, crushed, criticizing, boycott, statute, centurion, onset, turquoise,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7757 0.0183 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7254 0.0176 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7195 0.0177 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7102 0.0175 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7417 0.0176 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7205 0.0177 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6943 0.0175 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7212 0.0175 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7196 0.0178 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6633 0.0176 sec/batch
# Nearest to often: kinetics, mormons, strongholds, suffices, wicked, diaper, khadijah, fractions,
# Nearest to two: sibylla, est, solemnly, tough, madonna, rick, veteran, lancashire,
# Nearest to at: rods, corporate, subtext, bernhardt, fellowship, dupont, jorge, hire,
# Nearest to world: reporting, astrometric, mitrokhin, icj, mast, explosion, unbroken, cyrillic,
# Nearest to th: cecil, sizeable, careers, unfolded, notation, heavyweight, selling, shipments,
# Nearest to have: seamlessly, insolvent, exposed, subsystems, switches, anthrax, level, reckoned,
# Nearest to people: amidst, harming, leaflet, cassell, stifled, ills, tumor, gradient,
# Nearest to however: decayed, enmity, competent, agree, rifles, streaming, revenge, attribute,
# Nearest to articles: metre, fealty, ruthless, burkert, great, sutton, ramesses, neburg,
# Nearest to scale: governmental, definitively, prequel, suitability, anchor, defeat, wisest, brochure,
# Nearest to rise: rouse, misapplication, tem, amputation, annuity, proponent, wrench, terrence,
# Nearest to know: retrofitted, pda, false, these, cropland, anarcho, dictatorial, noor,
# Nearest to bbc: illustrations, espy, parenting, ups, fluoxetine, anymore, railroads, deregulation,
# Nearest to bill: communist, disestablished, publishes, fulani, lazarus, threw, live, dans,
# Nearest to active: slovakia, hanafi, inundation, golem, higham, freehold, negated, homyel,
# Nearest to derived: pressed, crushed, boycott, supplanting, criticizing, centurion, onset, turquoise,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6792 0.0183 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6596 0.0176 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6220 0.0176 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6308 0.0179 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6209 0.0179 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6351 0.0177 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6109 0.0134 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5337 0.0176 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5170 0.0174 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5273 0.0173 sec/batch
# Nearest to often: kinetics, mormons, suffices, strongholds, mimosa, diaper, fractions, wicked,
# Nearest to two: sibylla, est, five, three, solemnly, one, carlos, tough,
# Nearest to at: rods, bernhardt, corporate, subtext, dupont, fellowship, sly, shepherd,
# Nearest to world: reporting, icj, mitrokhin, astrometric, unbroken, mast, cyrillic, explosion,
# Nearest to th: cecil, heavyweight, careers, unfolded, sizeable, shipments, recognising, presided,
# Nearest to have: insolvent, exposed, seamlessly, subsystems, switches, anthrax, level, reckoned,
# Nearest to people: amidst, harming, leaflet, stifled, tumor, cassell, ills, hymen,
# Nearest to however: decayed, enmity, establish, competent, agree, attribute, suitcases, rifles,
# Nearest to articles: metre, fealty, burkert, ruthless, great, ramesses, neburg, sutton,
# Nearest to scale: suitability, governmental, anchor, countermeasures, laine, definitively, brochure, prequel,
# Nearest to rise: rouse, misapplication, amputation, tem, annuity, terrence, wrench, anthemius,
# Nearest to know: anarcho, retrofitted, false, pda, these, cropland, apoptosis, dictatorial,
# Nearest to bbc: illustrations, parenting, ups, espy, rhymed, fluoxetine, libby, deregulation,
# Nearest to bill: communist, disestablished, publishes, fulani, lazarus, threw, walter, dans,
# Nearest to active: slovakia, golem, inundation, hanafi, higham, atlases, homyel, negated,
# Nearest to derived: supplanting, pressed, crushed, boycott, centurion, onset, outstripped, sicherheitspolizei,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4836 0.0183 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5245 0.0178 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4451 0.0174 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5202 0.0174 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5190 0.0176 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4695 0.0171 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4657 0.0170 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4226 0.0171 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4453 0.0173 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4107 0.0177 sec/batch
# Nearest to often: kinetics, mormons, suffices, wicked, diaper, prophylaxis, strongholds, mimosa,
# Nearest to two: est, sibylla, five, three, solemnly, zero, undeniably, tough,
# Nearest to at: rods, adversarial, dupont, subtext, fellowship, bernhardt, shunters, lsap,
# Nearest to world: reporting, icj, mitrokhin, astrometric, plummet, manila, explosion, irl,
# Nearest to th: heavyweight, cecil, premiers, careers, sizeable, presided, unfolded, solidly,
# Nearest to have: seamlessly, subsystems, insolvent, exposed, anthrax, level, switches, reckoned,
# Nearest to people: amidst, leaflet, harming, stifled, ills, hymen, tumor, painda,
# Nearest to however: decayed, enmity, establish, scepticism, agree, suitcases, competent, attribute,
# Nearest to articles: fealty, metre, burkert, ramesses, great, ruthless, neburg, webpages,
# Nearest to scale: suitability, pln, countermeasures, note, brochure, anchor, seal, governmental,
# Nearest to rise: rouse, misapplication, amputation, tem, annuity, wrench, anthemius, terrence,
# Nearest to know: anarcho, retrofitted, false, pda, apoptosis, cropland, implicit, existence,
# Nearest to bbc: parenting, illustrations, espy, ups, rhymed, fluoxetine, norwalk, deregulation,
# Nearest to bill: communist, disestablished, publishes, walter, threw, kapor, fulani, weh,
# Nearest to active: slovakia, golem, inundation, hanafi, higham, atlases, skyline, homyel,
# Nearest to derived: supplanting, crushed, pressed, onset, centurion, sicherheitspolizei, outstripped, boycott,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4594 0.0182 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4089 0.0172 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4364 0.0180 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4028 0.0174 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4198 0.0178 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4259 0.0176 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3499 0.0171 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4069 0.0175 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4056 0.0173 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3777 0.0176 sec/batch
# Nearest to often: kinetics, mormons, suffices, diaper, prophylaxis, wicked, symbolism, strongholds,
# Nearest to two: est, three, five, sibylla, zero, one, undeniably, berthollet,
# Nearest to at: rods, subtext, adversarial, fellowship, shunters, inman, lsap, normalization,
# Nearest to world: reporting, mitrokhin, astrometric, icj, plummet, metabolize, manila, irl,
# Nearest to th: cecil, heavyweight, nd, presided, careers, emoticon, premiers, rd,
# Nearest to have: subsystems, exposed, seamlessly, insolvent, anthrax, reckoned, level, switches,
# Nearest to people: amidst, leaflet, harming, stifled, ills, hymen, bogomils, painda,
# Nearest to however: decayed, establish, enmity, suitcases, scepticism, competent, agree, attribute,
# Nearest to articles: fealty, burkert, metre, great, ramesses, neburg, webpages, pastiche,
# Nearest to scale: suitability, note, pln, countermeasures, batteries, governmental, inserted, trigonal,
# Nearest to rise: rouse, amputation, misapplication, annuity, anthemius, wrench, shrugged, tem,
# Nearest to know: false, anarcho, effeminate, retrofitted, cropland, apoptosis, implicit, pda,
# Nearest to bbc: ups, parenting, illustrations, espy, norwalk, fluoxetine, december, randal,
# Nearest to bill: communist, disestablished, walter, publishes, kapor, confessors, merrick, wiesenthal,
# Nearest to active: slovakia, inundation, golem, atlases, higham, hanafi, negated, skyline,
# Nearest to derived: onset, crushed, supplanting, sicherheitspolizei, centurion, pressed, turquoise, outstripped,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3603 0.0180 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3972 0.0171 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3436 0.0172 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3573 0.0169 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4333 0.0174 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3534 0.0174 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3702 0.0173 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3707 0.0171 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3429 0.0174 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3172 0.0175 sec/batch
# Nearest to often: kinetics, mormons, wicked, prophylaxis, mimosa, suffices, diaper, strongholds,
# Nearest to two: est, three, five, zero, one, sibylla, pledges, solemnly,
# Nearest to at: rods, adversarial, shunters, fellowship, inman, minimise, lsap, subtext,
# Nearest to world: reporting, icj, metabolize, mitrokhin, astrometric, plummet, continents, manila,
# Nearest to th: nd, cecil, rd, heavyweight, scramble, emoticon, grammaticus, century,
# Nearest to have: subsystems, seamlessly, exposed, anthrax, insolvent, reckoned, converts, switches,
# Nearest to people: amidst, harming, leaflet, stifled, ills, rem, painda, hymen,
# Nearest to however: decayed, establish, enmity, competent, suitcases, scepticism, agree, attribute,
# Nearest to articles: fealty, burkert, metre, webpages, mismeasure, pastiche, great, ramesses,
# Nearest to scale: suitability, guilds, pln, trigonal, governmental, batteries, note, coprocessor,
# Nearest to rise: rouse, misapplication, amputation, wrench, shrugged, annuity, anthemius, tem,
# Nearest to know: false, effeminate, implicit, anarcho, pda, retrofitted, exogamy, apoptosis,
# Nearest to bbc: ups, parenting, december, espy, illustrations, randal, deregulation, fluoxetine,
# Nearest to bill: communist, disestablished, kapor, wiesenthal, confessors, walter, publishes, blatant,
# Nearest to active: slovakia, inundation, atlases, golem, negated, hanafi, fisc, higham,
# Nearest to derived: onset, sicherheitspolizei, supplanting, pressed, doers, crushed, centurion, outstripped,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3298 0.0185 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3407 0.0176 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3811 0.0174 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3669 0.0174 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4047 0.0173 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2947 0.0176 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3073 0.0174 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3339 0.0176 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2445 0.0174 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2954 0.0171 sec/batch
# Nearest to often: kinetics, wicked, mormons, prophylaxis, criticizes, symbolism, transplantation, linguistics,
# Nearest to two: est, five, three, zero, one, four, seven, sibylla,
# Nearest to at: adversarial, rods, fellowship, diagram, lsap, subtext, inman, minimise,
# Nearest to world: reporting, metabolize, mitrokhin, icj, manila, plummet, ak, astrometric,
# Nearest to th: nd, rd, cecil, heavyweight, scramble, century, grammaticus, emoticon,
# Nearest to have: subsystems, seamlessly, anthrax, exposed, converts, reckoned, insolvent, sober,
# Nearest to people: amidst, leaflet, harming, stifled, ills, hymen, toonami, rem,
# Nearest to however: decayed, establish, suitcases, competent, enmity, scepticism, pulsar, oneself,
# Nearest to articles: fealty, burkert, webpages, mismeasure, metre, online, pastiche, othniel,
# Nearest to scale: guilds, governmental, suitability, trigonal, pln, coprocessor, wisest, batteries,
# Nearest to rise: rouse, amputation, wrench, misapplication, sanatorium, rampart, annuity, anthemius,
# Nearest to know: false, effeminate, exogamy, retrofitted, pda, implicit, anarcho, mothering,
# Nearest to bbc: december, deregulation, randal, ups, parenting, archie, mascots, bullies,
# Nearest to bill: communist, disestablished, kapor, parker, publishes, wiesenthal, confessors, walter,
# Nearest to active: slovakia, inundation, hanafi, golem, atlases, fisc, negated, exarch,
# Nearest to derived: supplanting, onset, sicherheitspolizei, doers, crushed, outstripped, centurion, nagaland,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3141 0.0177 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2833 0.0175 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3258 0.0083 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2645 0.0172 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2189 0.0176 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2140 0.0178 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2020 0.0174 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2547 0.0173 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2277 0.0176 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1925 0.0178 sec/batch
# Nearest to often: kinetics, mormons, wicked, prophylaxis, diaper, symbolism, mimosa, linguistics,
# Nearest to two: five, est, three, zero, one, four, seven, sibylla,
# Nearest to at: lsap, adversarial, rods, diagram, inking, inman, tall, minimise,
# Nearest to world: reporting, metabolize, ak, mitrokhin, continents, consoles, irl, manila,
# Nearest to th: nd, rd, century, heavyweight, grammaticus, cecil, ruins, graeco,
# Nearest to have: subsystems, seamlessly, exposed, anthrax, reckoned, sober, insolvent, conakry,
# Nearest to people: amidst, harming, leaflet, toonami, rem, ills, stifled, hymen,
# Nearest to however: decayed, establish, suitcases, competent, enmity, attribute, pulsar, scepticism,
# Nearest to articles: fealty, online, burkert, mismeasure, webpages, great, ordinated, othniel,
# Nearest to scale: guilds, pln, trigonal, coprocessor, suitability, note, governmental, alkenes,
# Nearest to rise: rouse, anthemius, sanatorium, amputation, wrench, misapplication, tem, trillian,
# Nearest to know: false, effeminate, exogamy, retrofitted, anarcho, implicit, subtle, mothering,
# Nearest to bbc: december, ups, parenting, deregulation, bullies, randal, archie, smoker,
# Nearest to bill: communist, disestablished, kapor, wiesenthal, ansel, parker, confessors, hillary,
# Nearest to active: slovakia, inundation, negated, atlases, fisc, hanafi, golem, exarch,
# Nearest to derived: sicherheitspolizei, onset, supplanting, doers, outstripped, crushed, turquoise, nagaland,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2697 0.0185 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2031 0.0177 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2198 0.0173 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1289 0.0175 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2063 0.0177 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1752 0.0171 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1661 0.0171 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1719 0.0167 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1990 0.0167 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1680 0.0174 sec/batch
# Nearest to often: kinetics, prophylaxis, wicked, linguistics, mormons, mimosa, additional, mathit,
# Nearest to two: est, five, three, zero, one, four, seven, webpage,
# Nearest to at: lsap, adversarial, diagram, rods, tall, minimise, ronaldo, inman,
# Nearest to world: metabolize, reporting, ak, continents, mitrokhin, manila, consoles, gauge,
# Nearest to th: nd, rd, century, heavyweight, notation, grammaticus, scramble, graeco,
# Nearest to have: anthrax, seamlessly, subsystems, exposed, sober, converts, insolvent, reckoned,
# Nearest to people: amidst, harming, leaflet, rem, ills, stifled, toonami, hymen,
# Nearest to however: decayed, establish, suitcases, competent, pulsar, scepticism, rifles, enmity,
# Nearest to articles: online, fealty, webpages, burkert, pdf, mismeasure, othniel, downloadable,
# Nearest to scale: guilds, pln, coprocessor, trigonal, note, alkenes, governmental, wisest,
# Nearest to rise: rouse, anthemius, misapplication, sanatorium, inexpensive, wrench, amputation, rampart,
# Nearest to know: effeminate, false, exogamy, retrofitted, say, pda, mothering, implicit,
# Nearest to bbc: december, ups, deregulation, bullies, parenting, smoker, randal, sec,
# Nearest to bill: communist, disestablished, kapor, merrick, hillary, wiesenthal, blatant, publishes,
# Nearest to active: slovakia, inundation, hanafi, turnout, fisc, atlases, negated, golem,
# Nearest to derived: sicherheitspolizei, onset, doers, supplanting, turquoise, outstripped, nagaland, hartree,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1938 0.0182 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2028 0.0175 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1678 0.0172 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1807 0.0170 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1761 0.0174 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1820 0.0174 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1872 0.0177 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1713 0.0175 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1571 0.0175 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1673 0.0174 sec/batch
# Nearest to often: kinetics, prophylaxis, wicked, linguistics, mormons, mimosa, transplantation, diaper,
# Nearest to two: three, zero, est, five, one, four, seven, six,
# Nearest to at: adversarial, lsap, fellowship, diagram, avalanche, marries, minimise, inking,
# Nearest to world: metabolize, reporting, ak, continents, manila, mitrokhin, consoles, dll,
# Nearest to th: nd, century, rd, notation, cecil, heavyweight, scramble, grammaticus,
# Nearest to have: seamlessly, subsystems, anthrax, integral, sober, reckoned, converts, are,
# Nearest to people: amidst, harming, ills, leaflet, rem, stifled, toonami, painda,
# Nearest to however: establish, decayed, suitcases, competent, scepticism, pulsar, enmity, rifles,
# Nearest to articles: online, webpages, pdf, mismeasure, downloadable, burkert, fealty, references,
# Nearest to scale: guilds, pln, coprocessor, trigonal, batteries, note, suitability, bahia,
# Nearest to rise: rouse, anthemius, amputation, sanatorium, misapplication, rampart, wrench, reining,
# Nearest to know: effeminate, exogamy, false, say, retrofitted, subtle, implicit, mothering,
# Nearest to bbc: december, ups, bullies, deregulation, smoker, parenting, mascots, presse,
# Nearest to bill: communist, kapor, disestablished, hillary, merrick, wiesenthal, ansel, parker,
# Nearest to active: slovakia, inundation, negated, atlases, exarch, hanafi, turnout, fisc,
# Nearest to derived: doers, onset, sicherheitspolizei, supplanting, turquoise, decimus, nagaland, outstripped,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1863 0.0184 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1534 0.0173 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1919 0.0175 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2102 0.0172 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1457 0.0175 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1199 0.0173 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1853 0.0173 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1279 0.0174 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2011 0.0174 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2090 0.0174 sec/batch
# Nearest to often: kinetics, wicked, mormons, prophylaxis, mimosa, linguistics, strongholds, criticizes,
# Nearest to two: three, five, zero, one, est, four, seven, six,
# Nearest to at: marries, adversarial, fellowship, aerom, lsap, inman, avalanche, york,
# Nearest to world: reporting, metabolize, ak, continents, mitrokhin, manila, consoles, leblanc,
# Nearest to th: nd, century, rd, cecil, notation, grammaticus, scramble, graeco,
# Nearest to have: seamlessly, reckoned, truthfulness, richland, anthrax, converts, relegating, extermination,
# Nearest to people: amidst, harming, ills, rem, toonami, leaflet, ethnic, stifled,
# Nearest to however: establish, decayed, suitcases, competent, enmity, scepticism, pass, pulsar,
# Nearest to articles: online, webpages, mismeasure, pdf, references, fealty, downloadable, othniel,
# Nearest to scale: guilds, pln, coprocessor, trigonal, wisest, governmental, anchor, bahia,
# Nearest to rise: rouse, anthemius, sanatorium, rampart, misapplication, wrench, stephens, century,
# Nearest to know: effeminate, say, exogamy, false, retrofitted, mothering, frightful, your,
# Nearest to bbc: december, june, bullies, ups, smoker, holidays, randal, deregulation,
# Nearest to bill: communist, hillary, disestablished, kapor, wiesenthal, parker, ansel, confessors,
# Nearest to active: slovakia, inundation, exarch, fisc, negated, oligarchic, turnout, hanafi,
# Nearest to derived: doers, supplanting, sicherheitspolizei, onset, turquoise, outstripped, nagaland, decimus,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2142 0.0179 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1371 0.0174 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1656 0.0173 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1233 0.0175 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0459 0.0173 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1322 0.0174 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1240 0.0174 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1041 0.0173 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1852 0.0035 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1248 0.0174 sec/batch
# Nearest to often: kinetics, mormons, mimosa, prophylaxis, wicked, linguistics, chekhov, strongholds,
# Nearest to two: zero, three, five, one, est, four, seven, six,
# Nearest to at: lsap, diagram, avalanche, adversarial, marries, ramzi, iota, tall,
# Nearest to world: metabolize, reporting, ak, continents, mitrokhin, dll, history, irl,
# Nearest to th: nd, century, rd, notation, cecil, graeco, scramble, grammaticus,
# Nearest to have: seamlessly, integral, subsystems, anthrax, reckoned, conceivable, converts, richland,
# Nearest to people: harming, amidst, toonami, ethnic, rem, ills, painda, hymen,
# Nearest to however: establish, suitcases, decayed, competent, enmity, rifles, scepticism, pulsar,
# Nearest to articles: online, webpages, pdf, mismeasure, references, downloadable, fealty, similars,
# Nearest to scale: guilds, pln, trigonal, coprocessor, wisest, note, reductionist, alkenes,
# Nearest to rise: rouse, rampart, sanatorium, century, stephens, anthemius, misapplication, wrench,
# Nearest to know: effeminate, say, exogamy, retrofitted, false, striving, mothering, your,
# Nearest to bbc: december, ups, holidays, bullies, june, smoker, deregulation, listing,
# Nearest to bill: communist, kapor, hillary, disestablished, merrick, adjust, ansel, parker,
# Nearest to active: slovakia, inundation, exarch, fisc, negated, environment, mdc, oligarchic,
# Nearest to derived: doers, supplanting, sicherheitspolizei, hartree, turquoise, outstripped, nagaland, onset,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0777 0.0184 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0715 0.0174 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0874 0.0175 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0485 0.0170 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0673 0.0171 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0436 0.0175 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0882 0.0175 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0800 0.0173 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1268 0.0174 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0364 0.0175 sec/batch
# Nearest to often: kinetics, wicked, mormons, prophylaxis, mimosa, linguistics, additional, diaper,
# Nearest to two: zero, three, five, one, est, four, seven, six,
# Nearest to at: lsap, to, avalanche, was, marries, epp, shunters, adversarial,
# Nearest to world: metabolize, continents, ak, reporting, history, manila, gauge, consoles,
# Nearest to th: nd, century, rd, notation, cecil, grammaticus, graeco, scramble,
# Nearest to have: anthrax, seamlessly, integral, are, subsystems, ba, rrebro, sober,
# Nearest to people: amidst, harming, ethnic, ills, rem, hymen, toonami, painda,
# Nearest to however: establish, suitcases, decayed, enmity, competent, scepticism, rifles, pass,
# Nearest to articles: online, webpages, pdf, mismeasure, references, downloadable, fealty, globalisation,
# Nearest to scale: guilds, pln, trigonal, wisest, coprocessor, reductionist, governmental, note,
# Nearest to rise: rouse, sanatorium, anthemius, stephens, rampart, century, multiracial, bolan,
# Nearest to know: exogamy, say, effeminate, false, mothering, striving, retrofitted, lug,
# Nearest to bbc: december, bullies, deregulation, ups, holidays, parenting, listing, aired,
# Nearest to bill: communist, hillary, adjust, merrick, kapor, disestablished, ansel, gair,
# Nearest to active: slovakia, inundation, environment, fisc, atlases, mdc, negated, oligarchic,
# Nearest to derived: doers, sicherheitspolizei, supplanting, turquoise, hartree, nagaland, outstripped, onset,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0259 0.0183 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0237 0.0173 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0112 0.0173 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0364 0.0178 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0451 0.0173 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0439 0.0174 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0778 0.0177 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1291 0.0171 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0925 0.0173 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0563 0.0170 sec/batch
# Nearest to often: kinetics, wicked, mathit, prophylaxis, mormons, fingerprint, linguistics, mimosa,
# Nearest to two: zero, three, five, one, est, four, seven, six,
# Nearest to at: avalanche, lsap, to, diagram, iota, shunters, tall, minimise,
# Nearest to world: metabolize, continents, reporting, ak, history, gauge, mitrokhin, manila,
# Nearest to th: nd, century, rd, notation, grammaticus, cecil, heavyweight, nfc,
# Nearest to have: integral, anthrax, seamlessly, are, subsystems, conceivable, cuteness, reckoned,
# Nearest to people: harming, amidst, ethnic, ills, hymen, demographics, apus, rem,
# Nearest to however: establish, suitcases, decayed, scepticism, competent, pass, oneself, antitrust,
# Nearest to articles: online, webpages, references, downloadable, pdf, mismeasure, pollutants, globalisation,
# Nearest to scale: guilds, pln, coprocessor, trigonal, wisest, reductionist, governmental, note,
# Nearest to rise: rouse, anthemius, sanatorium, rampart, misapplication, stephens, bolan, fuels,
# Nearest to know: say, exogamy, effeminate, false, your, mothering, striving, lug,
# Nearest to bbc: december, bullies, ups, deregulation, holidays, parenting, lakers, june,
# Nearest to bill: communist, hillary, adjust, kapor, merrick, disestablished, ansel, coleman,
# Nearest to active: slovakia, inundation, environment, fisc, mdc, oligarchic, exarch, negated,
# Nearest to derived: doers, sicherheitspolizei, turquoise, supplanting, nagaland, hartree, outstripped, onset,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0801 0.0183 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0713 0.0175 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0597 0.0174 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0741 0.0173 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0716 0.0174 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0593 0.0174 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0545 0.0172 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0638 0.0174 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0718 0.0175 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0984 0.0174 sec/batch
# Nearest to often: kinetics, wicked, mormons, prophylaxis, mimosa, fingerprint, transplantation, mathit,
# Nearest to two: zero, three, five, one, est, four, seven, six,
# Nearest to at: avalanche, lsap, iota, to, marries, shunters, completed, lausanne,
# Nearest to world: metabolize, continents, history, reporting, ak, mitrokhin, gauge, theorists,
# Nearest to th: century, nd, rd, notation, grammaticus, graeco, twentieth, nfc,
# Nearest to have: cuteness, seamlessly, integral, anthrax, lichfield, converts, hesiod, are,
# Nearest to people: harming, ethnic, amidst, ills, sarmatian, rem, painda, stifled,
# Nearest to however: establish, suitcases, decayed, scepticism, rnu, competent, credence, antitrust,
# Nearest to articles: online, webpages, references, pdf, mismeasure, downloadable, pollutants, archaeoastronomy,
# Nearest to scale: guilds, pln, coprocessor, wisest, trigonal, governmental, fairchild, satellites,
# Nearest to rise: rouse, sanatorium, anthemius, stephens, bolan, century, rampart, proponent,
# Nearest to know: say, exogamy, frightful, your, effeminate, galloping, mothering, false,
# Nearest to bbc: december, bullies, holidays, ups, aired, week, parenting, celebrate,
# Nearest to bill: communist, hillary, adjust, kapor, disestablished, conservatism, merrick, ansel,
# Nearest to active: slovakia, exarch, inundation, oligarchic, fisc, mdc, environment, negated,
# Nearest to derived: doers, turquoise, supplanting, sicherheitspolizei, hartree, decimus, antique, nagaland,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0569 0.0179 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0208 0.0174 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0370 0.0177 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0661 0.0172 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0634 0.0172 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1225 0.0172 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1242 0.0172 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0347 0.0177 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0138 0.0166 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0774 0.0169 sec/batch
# Nearest to often: kinetics, wicked, prophylaxis, fingerprint, mimosa, mormons, transplantation, mathit,
# Nearest to two: zero, three, five, one, est, four, seven, six,
# Nearest to at: avalanche, marries, coolest, lsap, lausanne, iota, aerom, diagram,
# Nearest to world: continents, metabolize, reporting, history, mitrokhin, ak, gauge, consoles,
# Nearest to th: century, nd, rd, notation, twentieth, grammaticus, graeco, nfc,
# Nearest to have: seamlessly, cuteness, anthrax, integral, are, rrebro, relegating, converts,
# Nearest to people: harming, ethnic, amidst, emigration, americans, ills, demographics, bahasa,
# Nearest to however: establish, decayed, suitcases, scepticism, rnu, competent, antitrust, credence,
# Nearest to articles: online, mismeasure, webpages, references, pdf, downloadable, pollutants, globalisation,
# Nearest to scale: guilds, pln, wisest, governmental, ciudad, coprocessor, revived, trigonal,
# Nearest to rise: rouse, sanatorium, anthemius, bolan, stephens, rampart, fuels, century,
# Nearest to know: say, your, exogamy, you, galloping, false, striving, effeminate,
# Nearest to bbc: december, celebrate, bullies, week, holidays, listing, aired, parenting,
# Nearest to bill: communist, hillary, adjust, disestablished, kapor, merrick, ansel, publishes,
# Nearest to active: slovakia, exarch, fisc, oligarchic, environment, inundation, mdc, glycoproteins,
# Nearest to derived: doers, supplanting, turquoise, sicherheitspolizei, hartree, incan, pressed, antique,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9850 0.0174 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0320 0.0174 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0350 0.0184 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0441 0.0175 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0412 0.0173 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0715 0.0164 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0185 0.0171 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9906 0.0175 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0286 0.0177 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9718 0.0176 sec/batch
# Nearest to often: kinetics, wicked, mormons, prophylaxis, fingerprint, mimosa, strongholds, transplantation,
# Nearest to two: zero, three, one, five, four, seven, est, six,
# Nearest to at: avalanche, lsap, to, lausanne, marries, completed, epp, proceeded,
# Nearest to world: metabolize, continents, history, reporting, ak, mitrokhin, consoles, gauge,
# Nearest to th: century, nd, rd, notation, twentieth, nfc, scramble, grammaticus,
# Nearest to have: cuteness, integral, reckoned, seamlessly, syncope, anthrax, ba, hesiod,
# Nearest to people: harming, amidst, ethnic, ills, americans, toonami, hymen, bahasa,
# Nearest to however: establish, decayed, suitcases, scepticism, determinants, pulsar, competent, oneself,
# Nearest to articles: online, webpages, mismeasure, pdf, downloadable, references, pollutants, similars,
# Nearest to scale: guilds, pln, scales, ciudad, bahia, intonation, governmental, coprocessor,
# Nearest to rise: rouse, sanatorium, anthemius, bolan, stephens, rampart, multiracial, fuels,
# Nearest to know: say, exogamy, your, you, mothering, striving, galloping, frightful,
# Nearest to bbc: december, listing, celebrate, holidays, bullies, week, june, aired,
# Nearest to bill: hillary, communist, adjust, disestablished, kapor, merrick, ansel, coleman,
# Nearest to active: slovakia, exarch, fisc, oligarchic, environment, inundation, mdc, atlases,
# Nearest to derived: doers, sicherheitspolizei, turquoise, hartree, supplanting, incan, representational, antique,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0019 0.0180 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9503 0.0177 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0315 0.0172 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0227 0.0173 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0172 0.0177 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0025 0.0174 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9041 0.0175 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9622 0.0173 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9434 0.0177 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9671 0.0171 sec/batch
# Nearest to often: kinetics, wicked, mormons, prophylaxis, fingerprint, supporting, strongholds, mathit,
# Nearest to two: zero, three, five, one, four, est, seven, six,
# Nearest to at: avalanche, lsap, proceeded, completed, to, marries, epp, diagram,
# Nearest to world: metabolize, continents, history, reporting, ak, gauge, mitrokhin, jarkko,
# Nearest to th: century, nd, rd, notation, twentieth, scramble, grammaticus, graeco,
# Nearest to have: are, seamlessly, anthrax, cuteness, integral, coloured, syncope, reckoned,
# Nearest to people: harming, amidst, ethnic, toonami, emigration, ills, americans, demographics,
# Nearest to however: establish, scepticism, suitcases, decayed, pulsar, gradation, antitrust, determinants,
# Nearest to articles: online, webpages, downloadable, mismeasure, pdf, references, pollutants, artcyclopedia,
# Nearest to scale: guilds, pln, ciudad, governmental, scales, revived, bahia, coprocessor,
# Nearest to rise: rouse, sanatorium, bolan, anthemius, stephens, fuels, rampart, ouadda,
# Nearest to know: say, exogamy, your, mothering, you, galloping, frightful, partridge,
# Nearest to bbc: december, listing, aired, celebrate, week, holidays, bullies, june,
# Nearest to bill: adjust, hillary, communist, merrick, kapor, disestablished, ronnie, parker,
# Nearest to active: slovakia, environment, oligarchic, fisc, inundation, exarch, atlases, mdc,
# Nearest to derived: doers, sicherheitspolizei, turquoise, hartree, supplanting, incan, pressed, rep,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0106 0.0180 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9978 0.0175 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0056 0.0174 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9999 0.0172 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0420 0.0173 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9389 0.0174 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0080 0.0175 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0117 0.0173 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9705 0.0172 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9913 0.0173 sec/batch
# Nearest to often: kinetics, wicked, fingerprint, supporting, mathit, mormons, strongholds, prophylaxis,
# Nearest to two: zero, three, one, five, four, six, seven, est,
# Nearest to at: avalanche, lsap, to, proceeded, completed, epp, lausanne, global,
# Nearest to world: history, continents, metabolize, reporting, mitrokhin, theorists, gauge, ak,
# Nearest to th: century, nd, rd, notation, twentieth, grammaticus, bundesverfassungsgericht, scramble,
# Nearest to have: are, cuteness, anthrax, seamlessly, integral, lichfield, unfairly, been,
# Nearest to people: harming, ethnic, amidst, toonami, ills, americans, emigration, sarmatian,
# Nearest to however: scepticism, establish, rnu, suitcases, decayed, pulsar, subscribed, minorities,
# Nearest to articles: online, webpages, downloadable, references, mismeasure, pdf, pollutants, artcyclopedia,
# Nearest to scale: guilds, pln, scales, ciudad, governmental, reductionist, bahia, intonation,
# Nearest to rise: rouse, sanatorium, bolan, anthemius, cfo, bhaskara, proponent, stephens,
# Nearest to know: say, exogamy, your, galloping, you, mothering, frightful, partridge,
# Nearest to bbc: december, listing, aired, week, celebrate, holidays, june, presse,
# Nearest to bill: hillary, adjust, communist, merrick, kapor, disestablished, walter, ronnie,
# Nearest to active: slovakia, environment, oligarchic, fisc, exarch, inundation, sniffing, mdc,
# Nearest to derived: doers, sicherheitspolizei, turquoise, hartree, incan, supplanting, tzimtzum, rep,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0175 0.0180 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9837 0.0175 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9887 0.0172 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9978 0.0174 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0143 0.0171 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9994 0.0175 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9887 0.0176 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9632 0.0177 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9621 0.0171 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0219 0.0172 sec/batch
# Nearest to often: kinetics, wicked, strongholds, fingerprint, mormons, mimosa, supporting, denote,
# Nearest to two: zero, three, one, five, four, seven, six, est,
# Nearest to at: avalanche, to, proceeded, lsap, completed, lausanne, iota, was,
# Nearest to world: continents, history, metabolize, reporting, gauge, premiums, slobodan, theorists,
# Nearest to th: century, nd, rd, notation, twentieth, graeco, classical, scramble,
# Nearest to have: are, seamlessly, cuteness, integral, were, been, lichfield, be,
# Nearest to people: harming, ethnic, emigration, amidst, victims, americans, toonami, demographics,
# Nearest to however: scepticism, establish, rnu, pulsar, suitcases, was, determinants, antitrust,
# Nearest to articles: online, webpages, downloadable, mismeasure, references, pdf, artcyclopedia, pollutants,
# Nearest to scale: guilds, pln, ciudad, scales, revived, governmental, bahia, intonation,
# Nearest to rise: sanatorium, bolan, rouse, anthemius, bhaskara, cfo, stephens, proponent,
# Nearest to know: say, exogamy, your, galloping, you, mothering, i, retrofitted,
# Nearest to bbc: december, week, listing, aired, celebrate, june, holidays, presse,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8305 0.0175 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8847 0.0177 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8693 0.0175 sec/batch
# Nearest to often: such, kinetics, other, types, of, used, typically, boasts,
# Nearest to two: zero, three, one, four, five, six, nine, seven,
# Nearest to at: in, to, two, with, the, was, three, on,
# Nearest to world: metabolize, continents, history, mohandas, slobodan, jarkko, also, salt,
# Nearest to th: century, nd, rd, twentieth, notation, bundesverfassungsgericht, iis, sitar,
# Nearest to have: are, been, be, not, were, because, more, other,
# Nearest to people: harming, victims, emigration, rosenberg, soe, japonic, turkic, americans,
# Nearest to however: was, due, than, etymologies, not, some, quite, most,
# Nearest to articles: online, mismeasure, webpages, artcyclopedia, pollutants, ban, downloadable, username,
# Nearest to scale: scales, guilds, imi, during, nearly, pln, beat, ciudad,
# Nearest to rise: sanatorium, anthemius, lenses, bolan, cfo, meager, bhaskara, fuels,
# Nearest to know: say, i, you, striving, we, think, frightful, galloping,
# Nearest to bbc: december, listing, events, june, august, rated, presse, aired,
# Nearest to bill: adjust, bills, hillary, monmouth, ronnie, conservatism, confessors, westbound,
# Nearest to active: environment, odorless, exarch, oligarchic, metabolism, catabolism, sniffing, moored,
# Nearest to derived: origins, stemming, incan, sicherheitspolizei, vulgaris, doers, tzimtzum, scalpel,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8558 0.0180 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8578 0.0171 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8568 0.0170 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8531 0.0168 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8324 0.0172 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8823 0.0173 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8584 0.0177 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8382 0.0174 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8706 0.0172 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8944 0.0176 sec/batch
# Nearest to often: kinetics, such, types, strongholds, denote, other, boasts, prefer,
# Nearest to two: zero, three, one, four, five, six, nine, seven,
# Nearest to at: in, to, was, two, with, three, he, the,
# Nearest to world: metabolize, continents, history, jarkko, gelfand, slobodan, mohandas, see,
# Nearest to th: century, nd, rd, twentieth, notation, bundesverfassungsgericht, hagiography, iis,
# Nearest to have: been, are, not, be, were, other, because, more,
# Nearest to people: harming, turkic, victims, speak, japonic, emigration, ethnic, soe,
# Nearest to however: was, than, due, etymologies, not, quite, most, rnu,
# Nearest to articles: online, mismeasure, artcyclopedia, webpages, pollutants, username, ban, pdf,
# Nearest to scale: guilds, scales, during, nearly, imi, pln, ciudad, schulz,
# Nearest to rise: sanatorium, anthemius, meager, bolan, lenses, cfo, bhaskara, stephens,
# Nearest to know: say, i, striving, you, think, we, frightful, galloping,
# Nearest to bbc: december, listing, events, aired, presse, rated, august, june,
# Nearest to bill: hillary, adjust, bills, monmouth, ronnie, conservatism, assent, cessation,
# Nearest to active: environment, exarch, odorless, oligarchic, catabolism, glycoproteins, militaries, sniffing,
# Nearest to derived: incan, origins, stemming, doers, vulgaris, rep, melkite, tzimtzum,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8520 0.0183 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8794 0.0172 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8236 0.0175 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8444 0.0173 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8820 0.0175 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8470 0.0173 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.0171 0.0175 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8856 0.0174 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9029 0.0175 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8161 0.0177 sec/batch
# Nearest to often: such, kinetics, types, or, other, strongholds, denote, prefer,
# Nearest to two: zero, three, one, four, five, six, nine, seven,
# Nearest to at: in, to, he, two, was, with, the, three,
# Nearest to world: metabolize, continents, history, gelfand, mohandas, jarkko, mitrokhin, slobodan,
# Nearest to th: century, nd, rd, twentieth, notation, bundesverfassungsgericht, two, hagiography,
# Nearest to have: been, are, were, not, be, more, because, evidence,
# Nearest to people: victims, ethnic, harming, emigration, americans, rosenberg, soe, underrepresented,
# Nearest to however: was, than, etymologies, due, most, quite, not, rnu,
# Nearest to articles: online, mismeasure, artcyclopedia, pollutants, ban, webpages, username, external,
# Nearest to scale: scales, guilds, during, nearly, diatonic, imi, pln, severely,
# Nearest to rise: sanatorium, anthemius, bolan, lenses, cfo, meager, bhaskara, fuels,
# Nearest to know: say, you, striving, i, think, we, frightful, somehow,
# Nearest to bbc: december, listing, events, june, presse, day, august, rated,
# Nearest to bill: bills, adjust, hillary, monmouth, ronnie, assent, cessation, ansel,
# Nearest to active: environment, exarch, odorless, oligarchic, catabolism, metabolism, glycoproteins, militaries,
# Nearest to derived: origins, stemming, incan, tzimtzum, vulgaris, rep, refer, sicherheitspolizei,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8062 0.0180 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8678 0.0170 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7732 0.0176 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8828 0.0173 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8449 0.0174 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8291 0.0175 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9049 0.0102 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8109 0.0175 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8399 0.0175 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8295 0.0173 sec/batch
# Nearest to often: such, kinetics, types, boasts, or, denote, other, strongholds,
# Nearest to two: three, zero, four, one, five, six, seven, nine,
# Nearest to at: in, to, the, he, with, of, was, on,
# Nearest to world: metabolize, continents, history, gelfand, jarkko, mohandas, salt, chronos,
# Nearest to th: century, nd, rd, twentieth, bundesverfassungsgericht, notation, two, iis,
# Nearest to have: been, are, be, not, were, more, other, seems,
# Nearest to people: victims, harming, emigration, americans, ethnic, rosenberg, turkic, speak,
# Nearest to however: was, due, etymologies, not, than, quite, most, some,
# Nearest to articles: online, mismeasure, artcyclopedia, webpages, ban, pollutants, summary, orwell,
# Nearest to scale: scales, guilds, diatonic, during, imi, nearly, intonation, ciudad,
# Nearest to rise: sanatorium, lenses, anthemius, bolan, cfo, meager, bhaskara, fuels,
# Nearest to know: say, striving, i, you, think, we, look, your,
# Nearest to bbc: listing, december, events, august, june, day, presse, holidays,
# Nearest to bill: adjust, ronnie, monmouth, bills, hillary, assent, ansel, decrement,
# Nearest to active: environment, exarch, odorless, oligarchic, catabolism, metabolism, glycoproteins, sniffing,
# Nearest to derived: origins, stemming, incan, refer, vulgaris, tzimtzum, melkite, sicherheitspolizei,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8017 0.0180 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8493 0.0174 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8028 0.0175 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8491 0.0173 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8686 0.0172 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8219 0.0174 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8906 0.0173 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7477 0.0173 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8284 0.0175 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7614 0.0173 sec/batch
# Nearest to often: such, kinetics, or, types, boasts, are, denote, used,
# Nearest to two: three, zero, one, four, five, six, seven, nine,
# Nearest to at: to, in, the, with, was, two, for, first,
# Nearest to world: metabolize, continents, history, also, salt, mohandas, gelfand, jarkko,
# Nearest to th: century, nd, rd, twentieth, notation, bundesverfassungsgericht, two, iis,
# Nearest to have: been, are, be, not, more, other, were, because,
# Nearest to people: emigration, victims, ethnic, americans, speak, rosenberg, harming, japonic,
# Nearest to however: was, than, due, not, quite, some, in, etymologies,
# Nearest to articles: online, mismeasure, artcyclopedia, webpages, pollutants, ban, orwell, summary,
# Nearest to scale: scales, guilds, diatonic, nearly, during, imi, juana, beat,
# Nearest to rise: sanatorium, anthemius, lenses, bolan, cfo, meager, bhaskara, fuels,
# Nearest to know: say, striving, i, look, we, you, think, your,
# Nearest to bbc: listing, december, events, june, august, marxists, presse, aired,
# Nearest to bill: adjust, ronnie, bills, monmouth, hillary, assent, ansel, conservatism,
# Nearest to active: environment, odorless, exarch, oligarchic, militaries, catabolism, moored, metabolism,
# Nearest to derived: stemming, vulgaris, origins, sicherheitspolizei, incan, scalpel, refer, today,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7662 0.0178 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8415 0.0177 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8640 0.0178 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8375 0.0175 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8153 0.0173 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9014 0.0170 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8239 0.0174 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8166 0.0174 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8382 0.0177 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8319 0.0173 sec/batch
# Nearest to often: such, kinetics, types, other, in, various, typically, or,
# Nearest to two: three, zero, one, four, five, six, nine, seven,
# Nearest to at: in, to, the, two, for, with, three, first,
# Nearest to world: metabolize, continents, history, gelfand, also, jarkko, mohandas, salt,
# Nearest to th: century, nd, rd, twentieth, bundesverfassungsgericht, notation, two, hagiography,
# Nearest to have: are, been, be, more, not, other, were, because,
# Nearest to people: ethnic, emigration, americans, victims, speak, harming, turkic, rosenberg,
# Nearest to however: was, due, than, not, has, quite, most, in,
# Nearest to articles: online, mismeasure, artcyclopedia, ban, pollutants, webpages, orwell, external,
# Nearest to scale: scales, guilds, during, nearly, diatonic, imi, beat, juana,
# Nearest to rise: sanatorium, bolan, anthemius, cfo, lenses, meager, bhaskara, fuels,
# Nearest to know: say, i, striving, we, you, think, look, t,
# Nearest to bbc: listing, december, events, june, presse, rated, aired, august,
# Nearest to bill: adjust, ronnie, monmouth, bills, hillary, conservatism, confessors, cessation,
# Nearest to active: environment, odorless, exarch, catabolism, oligarchic, metabolism, militaries, glycoproteins,
# Nearest to derived: stemming, origins, vulgaris, refer, incan, sicherheitspolizei, tzimtzum, scalpel,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8502 0.0181 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8627 0.0174 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8124 0.0175 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8495 0.0175 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8950 0.0174 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8404 0.0177 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8121 0.0175 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8449 0.0174 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8042 0.0174 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8154 0.0176 sec/batch
# Nearest to often: such, or, other, kinetics, in, of, for, various,
# Nearest to two: three, zero, four, one, five, six, seven, nine,
# Nearest to at: in, to, two, the, three, for, five, with,
# Nearest to world: continents, metabolize, history, gelfand, also, mohandas, salt, see,
# Nearest to th: century, nd, rd, twentieth, bundesverfassungsgericht, notation, two, hagiography,
# Nearest to have: are, been, be, not, were, other, more, there,
# Nearest to people: victims, ethnic, americans, emigration, harming, turkic, speak, rosenberg,
# Nearest to however: was, than, due, has, are, for, quite, most,
# Nearest to articles: online, mismeasure, artcyclopedia, ban, external, webpages, pollutants, pdf,
# Nearest to scale: scales, guilds, during, diatonic, nearly, imi, juana, severely,
# Nearest to rise: sanatorium, anthemius, lenses, bolan, meager, cfo, fuels, nomine,
# Nearest to know: say, we, you, i, striving, think, your, t,
# Nearest to bbc: listing, december, events, june, day, presse, rated, august,
# Nearest to bill: bills, adjust, ronnie, assent, monmouth, hillary, cessation, conservatism,
# Nearest to active: environment, odorless, exarch, catabolism, oligarchic, glycoproteins, militaries, metabolism,
# Nearest to derived: stemming, the, incan, original, origins, sicherheitspolizei, vulgaris, refer,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8672 0.0182 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8128 0.0176 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9146 0.0178 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8870 0.0178 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8699 0.0177 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8717 0.0177 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7815 0.0173 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8495 0.0177 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7322 0.0176 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8526 0.0176 sec/batch
# Nearest to often: such, kinetics, or, other, types, in, boasts, various,
# Nearest to two: zero, three, one, four, five, six, nine, seven,
# Nearest to at: in, to, with, the, two, for, on, he,
# Nearest to world: continents, metabolize, history, gelfand, salt, jarkko, active, mohandas,
# Nearest to th: century, nd, rd, twentieth, bundesverfassungsgericht, two, hagiography, notation,
# Nearest to have: been, are, not, be, more, were, other, and,
# Nearest to people: ethnic, victims, harming, americans, emigration, turkic, demographics, speak,
# Nearest to however: was, than, most, quite, due, are, not, has,
# Nearest to articles: online, mismeasure, artcyclopedia, ban, pollutants, webpages, external, pdf,
# Nearest to scale: scales, guilds, diatonic, nearly, during, beat, juana, messiaen,
# Nearest to rise: sanatorium, anthemius, lenses, bolan, cfo, meager, fuels, bhaskara,
# Nearest to know: say, i, you, we, striving, think, t, your,
# Nearest to bbc: listing, december, events, june, day, presse, rated, august,
# Nearest to bill: adjust, bills, ronnie, monmouth, hillary, assent, cessation, walter,
# Nearest to active: environment, exarch, odorless, oligarchic, world, militaries, catabolism, energized,
# Nearest to derived: stemming, incan, origins, vulgaris, refer, sicherheitspolizei, original, touma,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8373 0.0182 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8228 0.0172 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# WARNING:tensorflow:From /home/stephen/python/anaconda3/envs/dlnd/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
